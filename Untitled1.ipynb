# %% [markdown]
# <a href="https://colab.research.google.com/github/youssefbourais0310/Neural_Networks/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# checkout the lables of our data
import pandas as pd
labels_csv = pd.read_csv("/content/drive/MyDrive/dataset_anass/meduim_dataa.csv")
src ="/content/drive/MyDrive/dataset_anass/meduim_dataa.csv"
mysrc  = "/content/drive/MyDrive/dataset_anass/train/"
labels_csv = labels_csv.drop(["category_id"],axis = 1)
for i in range(2070) :
  labels_csv["file"][i] = labels_csv["file"][i][43:]
  labels_csv.to_csv(src, index=False)
  labels_csv.to_csv(src, index=False)

# %%
labels_csv
# Out:
#                                                    file                category
# 0     Nephrolepis_exaltata/02b9e99903baaafa12a006e87...    Nephrolepis_exaltata
# 1     Pelargonium_zonale/25c583cf0f9578b13ab971ae5f4...      Pelargonium_zonale
# 2     Pelargonium_graveolens/3f1c264d5568541452a6ec0...  Pelargonium_graveolens
# 3     Phyllanthus_tenellus/c44ec06c5ff2c560d7f5de1fd...    Phyllanthus_tenellus
# 4     Cirsium_arvense/3a4f0360a8cdcd7bdef709907a6a8f...         Cirsium_arvense
# ...                                                 ...                     ...
# 2066  Pelargonium_zonale/2d2e2b10dc6dae6c66c1341a64a...      Pelargonium_zonale
# 2067  Vaccaria_hispanica/9292384aa1961d1b6c9d78f3e1d...      Vaccaria_hispanica
# 2068  Mercurialis_annua/3b1c37e0976c93f0c9f3e5ad66e6...       Mercurialis_annua
# 2069  Pelargonium_graveolens/23c82aaec7d126f644d6969...  Pelargonium_graveolens
# 2070  /content/drive/MyDrive/dataset_anass/train/Nep...    Nephrolepis_exaltata
#
# ...

# %%
labels_csv  = labels_csv.drop(["category_id"],axis = 1)
labels_csv = labels_csv.drop(labels_csv.index[2071])
src ="/content/drive/MyDrive/dataset_anass/meduim_dataa.csv"

labels_csv.to_csv(src, index=False)

# %%
mysrc  = "/content/drive/MyDrive/dataset_anass/train/"
len(mysrc)
# Out:
# 43

# %%
src ="/content/drive/MyDrive/dataset_anass/meduim_dataa.csv"

for i in range(2070) :
  # if mysrc in labels_csv["file"][i] : 
  #  labels_csv["file"][i] = labels_csv["file"][i][43:]
  #  labels_csv.to_csv(src, index=False)
  row = labels_csv["file"][i][1:]
  print(row)
# Out:
# ephrolepis_exaltata/02b9e99903baaafa12a006e87a4cf3b4f236846a.jpg
# elargonium_zonale/25c583cf0f9578b13ab971ae5f44a3ba18760dad.jpg
# elargonium_graveolens/3f1c264d5568541452a6ec00271f3e58ec055c0e.jpg
# hyllanthus_tenellus/c44ec06c5ff2c560d7f5de1fdce33acd3db89882.jpg
# irsium_arvense/3a4f0360a8cdcd7bdef709907a6a8f2dab943acb.jpg
# elargonium_zonale/3e2a1e3fc1293089825f1c892cac0dc307f61b85.jpg
# elargonium_graveolens/44d4acbb3a8f6fdeddf2bf8c8b30c0dac38910aa.jpg
# accaria_hispanica/0e4a94be19edfc5e1243701855ffd51c2329f551.jpg
# yoseris_radiata/78944f216b5cd091eab4d3ea9660120ce935ff70.jpg
# hyllanthus_tenellus/d9e8d9d4f5d6e52e3606d6814fd7f9d9a3837f61.jpg
# ercurialis_annua/7f2eb29f65a22868030ea1a62a2af0b54a568c45.jpg
# accaria_hispanica/80dd92347e3c4b9aa4f6ed38edcf8218dd4ae6ca.jpg
# elargonium_zonale/65ade7f8c1c2df38ab9a938d186a6124411c9764.jpg
# irsium_arvense/2dc7dedd563f425eb1959f81230521f522885d69.jpg
# ephrolepis_exaltata/02eaf7477fd13d071901e8511dfe53e5a1ed6104.jpg
# ...

# %%
labels_csv["file"]
# Out:
# 0       Nephrolepis_exaltata/02b9e99903baaafa12a006e87...
# 1       Pelargonium_zonale/25c583cf0f9578b13ab971ae5f4...
# 2       Pelargonium_graveolens/3f1c264d5568541452a6ec0...
# 3       Phyllanthus_tenellus/c44ec06c5ff2c560d7f5de1fd...
# 4       Cirsium_arvense/3a4f0360a8cdcd7bdef709907a6a8f...
#                               ...
# 1540    Pelargonium_zonale/29cb24a710ff1cd565dabc65bd4...
# 1541    Pelargonium_zonale/4b4594d24826139bf7f5ef4c6e1...
# 1542    Hyoseris_radiata/8640ad76ad3542d6947bbf5d8254f...
# 1543                                                  NaN
# 2069                                                  NaN
# Name: file, Length: 1545, dtype: object

# %%
labels_csv
# Out:
#                                                    file  ... category_id
# 0     Nephrolepis_exaltata/02b9e99903baaafa12a006e87...  ...         NaN
# 1     Pelargonium_zonale/25c583cf0f9578b13ab971ae5f4...  ...         NaN
# 2     Pelargonium_graveolens/3f1c264d5568541452a6ec0...  ...         NaN
# 3     Phyllanthus_tenellus/c44ec06c5ff2c560d7f5de1fd...  ...         NaN
# 4     Cirsium_arvense/3a4f0360a8cdcd7bdef709907a6a8f...  ...         NaN
# ...                                                 ...  ...         ...
# 1540  Pelargonium_zonale/29cb24a710ff1cd565dabc65bd4...  ...         NaN
# 1541  Pelargonium_zonale/4b4594d24826139bf7f5ef4c6e1...  ...         NaN
# 1542  Hyoseris_radiata/8640ad76ad3542d6947bbf5d8254f...  ...         NaN
# 1543                                                NaN  ...         NaN
# 2069                                                NaN  ...
#
# [1545 rows x 3 columns]
