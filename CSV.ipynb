# %% [markdown]
# <a href="https://colab.research.google.com/github/youssefbourais0310/Neural_Networks/blob/main/CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/project_stage/pro.csv")
df
# Out:
#       f601766d-adb7-4aee-b8e9-c1693667d3f8.jpg 08278_Plantae_Tracheophyta_Magnoliopsida_Gentianales_Apocynaceae_Nerium_oleander ng_image_plants
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac.jpg 08278...
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f.jpg 08278...
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63.jpg 08278...
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12.jpg 08278...
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2.jpg 08278...
# ...                                                  ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df.jpg 06786...
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210.jpg 06786...
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4.jpg 06786...
# 18141  87ac7c83-bb87-4902-9824-2454009028ed.jpg 06786...
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6.jpg 06786...
#
# [18143 rows x 1 columns]

# %%
df['f601766d-adb7-4aee-b8e9-c1693667d3f8.jpg 08278_Plantae_Tracheophyta_Magnoliopsida_Gentianales_Apocynaceae_Nerium_oleander ng_image_plants'].str.split(' ')
# Out:
# 0        [7f87540d-092f-4d1e-933b-10ac5bacbfac.jpg, 082...
# 1        [cad9ae7b-2918-438a-a2fb-bd6abd5eb69f.jpg, 082...
# 2        [9f70c3e7-1370-47c2-aa75-6c7378bccc63.jpg, 082...
# 3        [52ba896b-bbd1-4456-b281-4e6d578c0c12.jpg, 082...
# 4        [7cba7f94-3b4c-4751-a7fb-2a697182deb2.jpg, 082...
#                                ...
# 18138    [a3384270-4fa9-4fee-8177-4574990721df.jpg, 067...
# 18139    [35d211d8-e39d-460d-a03f-bc99a3c19210.jpg, 067...
# 18140    [dc9e307a-9bab-4eac-b91d-2ee5cff94ed4.jpg, 067...
# 18141    [87ac7c83-bb87-4902-9824-2454009028ed.jpg, 067...
# 18142    [1ea390f2-9881-4520-beac-63f9fb5db4c6.jpg, 067...
# Name: f601766d-adb7-4aee-b8e9-c1693667d3f8.jpg 08278_Plantae_Tracheophyta_Magnoliopsida_Gentianales_Apocynaceae_Nerium_oleander ng_image_plants, Length: 18143, dtype: object

# %%
df1 = df['f601766d-adb7-4aee-b8e9-c1693667d3f8.jpg 08278_Plantae_Tracheophyta_Magnoliopsida_Gentianales_Apocynaceae_Nerium_oleander ng_image_plants'].str.split(' ', expand = True)

# %%
df1
# Out:
#                                               0  \
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac.jpg
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f.jpg
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63.jpg
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12.jpg
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2.jpg
# ...                                         ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df.jpg
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210.jpg
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4.jpg
# 18141  87ac7c83-bb87-4902-9824-2454009028ed.jpg
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6.jpg
#
#                                                        1                2
# 0      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...  ng_image_plants
# 1      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...  ng_image_plants
# 2      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...  ng_image_plants
# 3      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...  ng_image_plants
# ...

# %%
df1 = df1.iloc[:, :-1]

# %%
df1
# Out:
#                                               0  \
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac.jpg
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f.jpg
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63.jpg
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12.jpg
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2.jpg
# ...                                         ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df.jpg
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210.jpg
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4.jpg
# 18141  87ac7c83-bb87-4902-9824-2454009028ed.jpg
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6.jpg
#
#                                                        1
# 0      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 1      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 2      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 3      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 4      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1.to_csv('pro4.csv')

# %%
import pandas as pd
DF = pd.read_csv("/content/drive/MyDrive/project_stage/PRO.csv")
DF
# Out:
#                                              id  \
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac.jpg
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f.jpg
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63.jpg
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12.jpg
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2.jpg
# ...                                         ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df.jpg
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210.jpg
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4.jpg
# 18141  87ac7c83-bb87-4902-9824-2454009028ed.jpg
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6.jpg
#
#                                                    breed
# 0      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 1      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 2      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 3      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 4      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# ...

# %%
DF
# Out:
#                                              id  \
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac.jpg
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f.jpg
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63.jpg
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12.jpg
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2.jpg
# ...                                         ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df.jpg
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210.jpg
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4.jpg
# 18141  87ac7c83-bb87-4902-9824-2454009028ed.jpg
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6.jpg
#
#                                                    breed
# 0      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 1      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 2      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 3      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 4      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# ...

# %%
DF['id'] = DF['id'].str.replace('.jpg','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
DF
# Out:
#                                          id  \
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2
# ...                                     ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4
# 18141  87ac7c83-bb87-4902-9824-2454009028ed
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6
#
#                                                    breed
# 0      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 1      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 2      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 3      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# 4      08278_Plantae_Tracheophyta_Magnoliopsida_Genti...
# ...                                                  ...
# ...

# %%
DF["breed"] = DF["breed"].str[6:]

# %%
DF
# Out:
#                                          id  \
# 0      7f87540d-092f-4d1e-933b-10ac5bacbfac
# 1      cad9ae7b-2918-438a-a2fb-bd6abd5eb69f
# 2      9f70c3e7-1370-47c2-aa75-6c7378bccc63
# 3      52ba896b-bbd1-4456-b281-4e6d578c0c12
# 4      7cba7f94-3b4c-4751-a7fb-2a697182deb2
# ...                                     ...
# 18138  a3384270-4fa9-4fee-8177-4574990721df
# 18139  35d211d8-e39d-460d-a03f-bc99a3c19210
# 18140  dc9e307a-9bab-4eac-b91d-2ee5cff94ed4
# 18141  87ac7c83-bb87-4902-9824-2454009028ed
# 18142  1ea390f2-9881-4520-beac-63f9fb5db4c6
#
#                                                    breed
# 0      Plantae_Tracheophyta_Magnoliopsida_Gentianales...
# 1      Plantae_Tracheophyta_Magnoliopsida_Gentianales...
# 2      Plantae_Tracheophyta_Magnoliopsida_Gentianales...
# 3      Plantae_Tracheophyta_Magnoliopsida_Gentianales...
# 4      Plantae_Tracheophyta_Magnoliopsida_Gentianales...
# ...                                                  ...
# ...

# %%
df.to_csv(r'Z.csv')
